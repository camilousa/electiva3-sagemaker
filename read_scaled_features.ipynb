# %%
import pandas as pd

# %%
df = pd.read_parquet("s3://sagemaker-us-east-1-381492271173/heart/data/train/train_scaled.parquet")

# %%
df
# Out:
#      _c0     xs[0]     xs[1]     xs[2]     xs[3]     xs[4]     xs[5]  \
# 0      1  1.179169 -1.451778  1.109926  1.313810  0.392783 -0.428355
# 1      1 -0.061725 -1.451778  1.109926 -1.267275 -0.632250 -0.428355
# 2      0 -0.851385  0.685562 -0.875765 -1.267275  0.504604 -0.428355
# 3      1 -0.512960 -1.451778 -0.875765 -1.267275  0.113228 -0.428355
# 4      0  0.953552  0.685562 -0.875765 -0.120126  0.113228 -0.428355
# ..   ...       ...       ...       ...       ...       ...       ...
# 207    1 -2.317897 -1.451778  0.117081 -0.808416 -0.706798 -0.428355
# 208    1 -1.077002  0.685562  0.117081 -0.234841  1.119624 -0.428355
# 209    1  1.856020 -1.451778 -0.875765 -1.152560 -1.843652 -0.428355
# 210    0 -1.189811  0.685562 -0.875765 -0.693701 -1.470913 -0.428355
# 211    0 -1.077002  0.685562 -0.875765  0.568164  1.138261 -0.428355
#
#         xs[6]     xs[7]     xs[8]     xs[9]    xs[10]    xs[11]    xs[12]
# ...
